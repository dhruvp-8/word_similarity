# %%
pip install urllib
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install urllib
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more informations on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
from bs4 import BeautifulSoup
import urllib3
import re
urllib3.disable_warnings()
http = urllib3.PoolManager()
url = "https://en.wikipedia.org/wiki/Main_Page"
response = http.request('GET', url)
soup = BeautifulSoup(response.data, "html5lib")
links = soup.find("div", {"id": "bodyContent"}).findAll("a", href=re.compile("(/wiki/)+([a-zA-Z0-9_:()])+"))
for link in links:
    print(link['href'])
# Out:
# /wiki/Wikipedia
# /wiki/Free_content
# /wiki/Encyclopedia
# /wiki/Wikipedia:Introduction
# /wiki/Special:Statistics
# /wiki/English_language
# /wiki/Portal:Arts
# /wiki/Portal:Biography
# /wiki/Portal:Geography
# /wiki/Portal:History
# /wiki/Portal:Mathematics
# /wiki/Portal:Science
# /wiki/Portal:Society
# /wiki/Portal:Technology
# /wiki/Portal:Contents/Portals
# /wiki/File:Single_lycoperdon_perlatum.jpg
# /wiki/Lycoperdon_perlatum
# /wiki/Fungal
# /wiki/Agaricaceae
# /wiki/Puffball
# /wiki/Spores
# /wiki/Edible_mushroom
# /wiki/Gleba
# /wiki/Fruit_body
# /wiki/Poisonous_mushroom
# /wiki/Amanita
# /wiki/Amino_acid
# /wiki/Sterol
# /wiki/Extract
# /wiki/Antimicrobial
# /wiki/Antifungal_medication
# /wiki/Lycoperdon_perlatum
# /wiki/August_Meyszner
# /wiki/Candaules,_King_of_Lydia,_Shews_his_Wife_by_Stealth_to_Gyges,_One_of_his_Ministers,_as_She_Goes_to_Bed
# /wiki/S-50_(Manhattan_Project)
# /wiki/Wikipedia:Today%27s_featured_article/January_2018
# /wiki/Wikipedia:Featured_articles
# ...

# %%
from bs4 import BeautifulSoup
import urllib3

import re
import nltk
from nltk.tokenize import word_tokenize

from collections import Counter

urllib3.disable_warnings()
http = urllib3.PoolManager()
url = ["https://en.wikipedia.org/wiki/Cat","https://simple.wikipedia.org/wiki/Cat"]
fin = []
for j in range(0,len(url)):
    x = 0
    response = http.request('GET', url[j])
    soup = BeautifulSoup(response.data, "html5lib")
    ps = soup.find("div", {"id": "bodyContent"}).findAll("p")
    cat_wiki = ''
    for i in range(0, len(ps)):
        cat_wiki += ps[i].text
    fin.append(cat_wiki)    
#print("--------------------------------------------------Wikipedia Text------------------------------------------------------------ \n", fin[0])
#print("\n")
#print("---------------------------------------------------Simple Wikipedia Text------------------------------------------------------------- \n", fin[1])

tok1 = word_tokenize(fin[0])
tok2 = word_tokenize(fin[1])
p_tok1 = nltk.pos_tag(tok1)
p_tok2 = nltk.pos_tag(tok2)
for x in range(0,len(tok1)):
    if tok1[x] == '(' or tok1[x] == ')' or tok1[x] == '.' or tok1[x] == ',' or tok1[x] == '[' or tok1[x] == ']' or tok1[x] == "'" or tok1[x] == '.':
        tok1[x] = ''
    if tok1[x] != '':
        print(tok1[x])
# Out:
# Felis
# catus
# original
# combination
# 3
# Felis
# catus
# domestica
# invalid
# junior
# synonym
# 4
# The
# domestic
# cat
# 1
# 5
# Felis
# silvestris
# catus
# or
# Felis
# catus
# is
# a
# small
# typically
# furry
# carnivorous
# mammal
# They
# are
# often
# called
# house
# cats
# 6
# when
# kept
# as
# indoor
# pets
# or
# simply
# cats
# when
# there
# is
# no
# need
# to
# distinguish
# them
# from
# other
# felids
# and
# felines
# They
# are
# often
# valued
# by
# humans
# for
# companionship
# and
# for
# their
# ability
# to
# hunt
# vermin
# There
# are
# more
# than
# seventy
# cat
# breeds
# recognized
# by
# various
# cat
# registries.Cats
# are
# similar
# in
# anatomy
# to
# the
# other
# felids
# with
# a
# strong
# flexible
# body
# quick
# reflexes
# sharp
# retractable
# claws
# and
# teeth
# adapted
# to
# killing
# small
# prey
# Cat
# senses
# fit
# a
# crepuscular
# and
# predatory
# ecological
# niche
# Cats
# can
# hear
# sounds
# too
# faint
# or
# ...
